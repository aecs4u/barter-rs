# %% [markdown]
# # Joshi Part 7: Payoffs & Monte Carlo (Python)
#
# Python implementation of the PayOff classes and Simple Monte Carlo from
# *The Concepts and Practice of Mathematical Finance* by Mark S. Joshi.
#
# ## Topics
# - PayOff class hierarchy (Call, Put, Digital, DoubleDigital)
# - Simple Monte Carlo pricing for European options
# - Convergence table
# - Anti-thetic variance reduction

# %%
from barther.bridge import Call, DigitalCall, Put
from barther.bridge import monte_carlo_antithetic, monte_carlo_convergence, simple_monte_carlo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from barther.bridge import Call, DigitalCall, Put
#       2 from barther.bridge import monte_carlo_antithetic, monte_carlo_convergence, simple_monte_carlo
#
# ModuleNotFoundError: No module named 'barther'

# %% [markdown]
# ## 1. PayOff Classes
#
# Joshi uses C++ virtual inheritance for polymorphic payoffs.
# In Python we use abstract base classes.

# %%
# Test payoffs
call = Call(100)
put = Put(100)
dc = DigitalCall(100)

for spot in [90, 100, 110]:
    print(f"S={spot}: Call={call(spot):.1f}, Put={put(spot):.1f}, DigitalCall={dc(spot):.1f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Test payoffs
# ----> 2 call = Call(100)
#       3 put = Put(100)
#       4 dc = DigitalCall(100)
#
# NameError: name 'Call' is not defined

# %% [markdown]
# ## 2. Simple Monte Carlo
#
# Simulate GBM paths: $S(T) = S(0) \exp\left((r - \frac{\sigma^2}{2})T + \sigma\sqrt{T}Z\right)$
#
# where $Z \sim N(0,1)$.

# %%
# Price ATM call: S=100, K=100, r=5%, vol=20%, T=1
# call = Call(100)
price, se = simple_monte_carlo(call, 100, 0.05, 0.2, 1.0, 200_000)
print(f"MC Call Price: {price:.4f} ± {se:.4f}")
print(f"BS Exact:      10.4506")
print(f"95% CI:        [{price - 1.96*se:.4f}, {price + 1.96*se:.4f}]")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Price ATM call: S=100, K=100, r=5%, vol=20%, T=1
#       2 # call = Call(100)
# ----> 3 price, se = simple_monte_carlo(call, 100, 0.05, 0.2, 1.0, 200_000)
#       4 print(f"MC Call Price: {price:.4f} ± {se:.4f}")
#       5 print(f"BS Exact:      10.4506")
#
# NameError: name 'simple_monte_carlo' is not defined

# %% [markdown]
# ## 3. Convergence Table
#
# Track the MC estimate at powers of 2 to observe convergence.

# %%
# call = Call(100)
table = monte_carlo_convergence(call, 100, 0.05, 0.2, 1.0, 2**18)

print(f"{'Paths':>10} {'Mean':>14} {'Std Error':>14}")
print("-" * 40)
for paths, mean, se in table:
    print(f"{paths:>10} {mean:>14.6f} {se:>14.6f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # call = Call(100)
# ----> 2 table = monte_carlo_convergence(call, 100, 0.05, 0.2, 1.0, 2**18)
#       4 print(f"{'Paths':>10} {'Mean':>14} {'Std Error':>14}")
#       5 print("-" * 40)
#
# NameError: name 'monte_carlo_convergence' is not defined

# %% [markdown]
# ## 4. Anti-thetic Variance Reduction
#
# For each $Z$, also use $-Z$. The errors partially cancel.

# %%
# call = Call(100)

price_basic, se_basic = simple_monte_carlo(call, 100, 0.05, 0.2, 1.0, 100_000)
price_anti, se_anti = monte_carlo_antithetic(call, 100, 0.05, 0.2, 1.0, 100_000)

print(f"Basic MC:     {price_basic:.4f} ± {se_basic:.4f}")
print(f"Anti-thetic:  {price_anti:.4f} ± {se_anti:.4f}")
print(f"Variance reduction: {se_basic/se_anti:.1f}x")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # call = Call(100)
# ----> 3 price_basic, se_basic = simple_monte_carlo(call, 100, 0.05, 0.2, 1.0, 100_000)
#       4 price_anti, se_anti = monte_carlo_antithetic(call, 100, 0.05, 0.2, 1.0, 100_000)
#       6 print(f"Basic MC:     {price_basic:.4f} ± {se_basic:.4f}")
#
# NameError: name 'simple_monte_carlo' is not defined
